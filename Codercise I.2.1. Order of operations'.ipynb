# %% [markdown]
# <h3><font color="#004D7F" size=5>Codercise I.2.1. Order of operations</font></h3>

# %% [markdown]
# **The code below is a quantum function with all the gates from the circuit shown below. However, the gates are out of order! Re-arrange the lines of the function to match the order of operations in the circuit.**

# %% [markdown]
# <img src="../../pictures/Codercise_I_2_1.png" align="center" width="300">

# %%
import pennylane as qml

# %%
def my_circuit(theta, phi):
    ##################
    qml.CNOT(wires=[0,1])
    qml.RX(theta, wires=2)
    qml.Hadamard(wires=0)
    qml.CNOT(wires=[2,0])
    qml.YY(phi, wires=1)
    ##################

    # REORDER THESE 5 GATES TO MATCH THE CIRCUIT IN PICTURE



    # This is the measurement; we return the probabilities of all possible output states
    # You'll learn more about what types of measurements are available in a later node
    return qml.probs(wires=[0,1,2])
